# %% [markdown]
# # Exercise 1

# %% [markdown]
# # (a)

# %%
import numpy as np

# %% [markdown]
# # (b)

# %%
import matplotlib.pyplot as plt
import random as rd

# %% [markdown]
# # (c)

# %%
S_0 = 100
mu = 0.06
sigma = 0.20
sigma2 = sigma**2
n = 365*10
dt = 1.0/365.0
sdt = np.sqrt(dt)
W_t= np.random.randn(n)
dz = W_t * sdt

S = S_0 * np.exp(np.cumsum(mu*dt - 0.5*sigma2*dt + sigma*dz))

time = np.arange(0,10,dt)

# %% [markdown]
# # (d)

# %%
plt.plot(time,S,label = 'Stock  price' , color = 'green')
plt.legend()
plt.grid()
plt.plot()
# Out:
# []

# %% [markdown]
# # (e)

# %%
C_return = []
D_return = []
for i in range(1,n):
    C_return.append( np.log(1+((S[i]-S[i-1])/S[i-1])) )
    D_return.append( (S[i]-S[i-1])/S[i-1] )

# %% [markdown]
# # (f)

# %%
plt.plot(time[1:len(time)],C_return,label = 'Log Return', color = 'purple')
plt.legend()
plt.grid()

# %% [markdown]
# # (g)

# %%
print('The annualized mean is %1.4f'%(np.mean(C_return)*365))
print('The annualized standard deviation is %1.4f'%(np.std(C_return)*np.sqrt(365)))
# Out:
# The annualized mean is 0.0497
# The annualized standard deviation is 0.2001

# %% [markdown]
# # Exercise 2

# %% [markdown]
# # (a)

# %%
import pandas as pd

# %% [markdown]
# # (b)

# %%
index = pd.period_range(start='1950-01-01',end='2021-12-31',freq='D')
n = len(index)
dt = 72/n
sdt = np.sqrt(dt)
W_t= np.random.randn(n)
dz = W_t * sdt
data = S_0 * np.exp(np.cumsum(mu*dt - 0.5*sigma2*dt + sigma*dz))
daily_share_price = pd.Series(data,index)

# %% [markdown]
# # (c)

# %%
print('Our sample has ', n , ' observations')
daily_share_price.plot(label = 'Daily share price', color = 'green')
plt.legend()
plt.grid()
# Out:
# Our sample has  26298  observations

# %% [markdown]
# # (d)

# %%
monthly_share_price = daily_share_price.resample('M').mean()
new_n = len(monthly_share_price)
print('Our new sample has ', new_n , ' observations')
# Out:
# Our new sample has  864  observations

# %% [markdown]
# # (e)

# %%
monthly_share_price.plot(label = 'Monthly share price', color = 'green')
plt.legend()
plt.grid()

# %% [markdown]
# # Exercise 3

# %% [markdown]
# # (a)

# %%
daily_log_return = np.log(daily_share_price/daily_share_price.shift(1))
weekly_share_price = daily_share_price.resample('W').first()
weekly_log_return = np.log(weekly_share_price/weekly_share_price.shift(1))
monthly_share_price = daily_share_price.resample('M').first()
monthly_log_return = np.log(monthly_share_price/monthly_share_price.shift(1))

# %% [markdown]
# # (b)

# %%
print('Summary Statistics for daily log returns are: ')
print(daily_log_return.describe())

print('Summary Statistics for weekly log returns are: ')
print(weekly_log_return.describe())

print('Summary Statistics for monthly log returns are: ')
print(monthly_log_return.describe())
# Out:
# Summary Statistics for daily log returns are:
# count    26297.000000
# mean         0.000201
# std          0.010452
# min         -0.048322
# 25%         -0.006884
# 50%          0.000202
# 75%          0.007214
# max          0.040563
# dtype: float64
# Summary Statistics for weekly log returns are:
# count    3757.000000
# mean        0.001413
# std         0.027656
# min        -0.082298
# 25%        -0.017058
# 50%         0.000789
# 75%         0.020133
# max         0.109706
# dtype: float64
# Summary Statistics for monthly log returns are:
# count    863.000000
# mean       0.006114
# std        0.059754
# min       -0.189792
# 25%       -0.030406
# 50%        0.006352
# 75%        0.047231
# max        0.206009
# dtype: float64

# %% [markdown]
# # (c)

# %%
print('The annualized mean and standard deviation of the daily log returns are respectively', 365*daily_log_return.mean() , 'and ',np.sqrt(365)*daily_log_return.std())
print('The annualized mean and standard deviation of the weekly log returns are respectively', 52*weekly_log_return.mean() , 'and ',np.sqrt(52)*weekly_log_return.std())
print('The annualized mean and standard deviation of the monthly log returns are respectively', 12*monthly_log_return.mean() , 'and ',np.sqrt(12)*monthly_log_return.std())
# Out:
# The annualized mean and standard deviation of the daily log returns are respectively 0.07354106594107125 and  0.19969149724807475
# The annualized mean and standard deviation of the weekly log returns are respectively 0.07349214529129311 and  0.1994278366704936
# The annualized mean and standard deviation of the monthly log returns are respectively 0.07337157038472687 and  0.20699356232260047

# %% [markdown]
# # (d)

# %%
daily_rolling_annualized_mean = 365*daily_log_return.rolling(365, center = True).mean()
daily_rolling_annualized_std = np.sqrt(365)*daily_log_return.rolling(365,center = True).std()

weekly_rolling_annualized_mean = 52*weekly_log_return.rolling(52, center = True).mean()
weekly_rolling_annualized_std = np.sqrt(52)*weekly_log_return.rolling(52,center = True).std()

monthly_rolling_annualized_mean = 12*monthly_log_return.rolling(12, center = True).mean()
monthly_rolling_annualized_std = np.sqrt(12)*monthly_log_return.rolling(12,center = True).std()

# %%
daily_rolling_annualized_mean.plot(label = 'Daily', color = 'green')
weekly_rolling_annualized_mean.plot(label = 'Weekly' , color = 'blue')
monthly_rolling_annualized_mean.plot(label = 'Monthly' , color = 'red')
plt.legend()
plt.grid()

# %%
daily_rolling_annualized_std.plot(label = 'Daily', color = 'green')
weekly_rolling_annualized_std.plot(label = 'Weekly' , color = 'blue')
monthly_rolling_annualized_std.plot(label = 'Monthly' , color = 'red')
plt.legend()
plt.grid()

# %% [markdown]
# # (e)

# %% [raw]
# Discuter ce que l'on obtient à la question précedente

# %% [markdown]
# # (f)

# %%
daily_annualized_mean = daily_log_return.resample('Y').agg(lambda x: x.mean()*365)
daily_annualized_std = daily_log_return.resample('Y').agg(lambda x: (x**2).mean() * 365)

weekly_annualized_mean = weekly_log_return.resample('Y').agg(lambda x: x.mean()*52)
weekly_annualized_std = weekly_log_return.resample('Y').agg(lambda x: (x**2).mean() * 52)

monthly_annualized_mean = monthly_log_return.resample('Y').agg(lambda x: x.mean()*12)
monthly_annualized_std = monthly_log_return.resample('Y').agg(lambda x: (x**2).mean() * 12)

# %%
daily_annualized_mean.plot(label = 'Daily', color = 'green')
weekly_annualized_mean.plot(label = 'Weekly' , color = 'blue')
monthly_annualized_mean.plot(label = 'Monthly' , color = 'red')
plt.legend()
plt.grid()

# %%
daily_annualized_std.plot(label = 'Daily', color = 'green')
weekly_annualized_std.plot(label = 'Weekly' , color = 'blue')
monthly_annualized_std.plot(label = 'Monthly' , color = 'red')
plt.legend()
plt.grid()

# %%
print('The mean and variance of the annualized mean of the daily log returns are respectively', daily_annualized_mean.mean() , 'and ',daily_annualized_mean.var())
print('The mean and variance of the annualized mean of the monthly log returns are respectively', monthly_annualized_mean.mean() , 'and ',monthly_annualized_mean.var())
# Out:
# The mean and variance of the annualized mean of the daily log returns are respectively 0.07359622737203594 and  0.04022898962444743
# The mean and variance of the annualized mean of the monthly log returns are respectively 0.07341797480898102 and  0.04536728229717385

# %%
print('The mean and variance of the annualized standard deviation of the daily log returns are respectively', daily_annualized_std.mean() , 'and ',daily_annualized_std.var())
print('The mean and varaince of the annualized standard deviation of the monthly log returns are respectively', monthly_annualized_std.mean() , 'and ',monthly_annualized_std.var())
# Out:
# The mean and variance of the annualized standard deviation of the daily log returns are respectively 0.03988970945268613 and  9.039097570186713e-06
# The mean and varaince of the annualized standard deviation of the monthly log returns are respectively 0.04323817524751709 and  0.0003604878678570965
